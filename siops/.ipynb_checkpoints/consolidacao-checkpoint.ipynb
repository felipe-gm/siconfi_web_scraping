# %%
import pandas as pd

# %%
df_ibge = pd.read_csv('ibge.csv')
df_ibge
# Out:
#       Cod Municipio            REGIAO  COD UF                UF  \
# 0           1100015         1 - Norte      11          Rondônia
# 1           1100023         1 - Norte      11          Rondônia
# 2           1100031         1 - Norte      11          Rondônia
# 3           1100049         1 - Norte      11          Rondônia
# 4           1100056         1 - Norte      11          Rondônia
# ...             ...               ...     ...               ...
# 5565        5222005  5 - Centro-Oeste      52             Goiás
# 5566        5222054  5 - Centro-Oeste      52             Goiás
# 5567        5222203  5 - Centro-Oeste      52             Goiás
# 5568        5222302  5 - Centro-Oeste      52             Goiás
# 5569        5300108  5 - Centro-Oeste      53  Distrito Federal
#
#                  NOME MUNIC
# 0     Alta Floresta D'Oeste
# 1                 Ariquemes
# 2                    Cabixi
# 3                    Cacoal
# 4                Cerejeiras
# ...

# %%
for row in df[['UF','Cod Municipio']]

# %%
import glob
files = glob.glob('raw/*/*')

# %%
files
# Out:
# ['raw/50_500320/2019_receitas.csv',
#  'raw/50_500320/2019_despesas.csv',
#  'raw/41_411170/2019_receitas.csv',
#  'raw/41_411170/2019_despesas.csv',
#  'raw/31_315840/2019_receitas.csv',
#  'raw/31_315840/2019_despesas.csv',
#  'raw/31_311190/2019_receitas.csv',
#  'raw/31_311190/2019_despesas.csv',
#  'raw/41_410160/2019_receitas.csv',
#  'raw/41_410160/2019_despesas.csv',
#  'raw/35_355250/2019_receitas.csv',
#  'raw/35_355250/2019_despesas.csv',
#  'raw/29_291420/2019_receitas.csv',
#  'raw/29_291420/2020_despesas.csv',
#  'raw/29_291420/2020_receitas.csv',
#  'raw/29_291420/2019_despesas.csv',
#  'raw/42_420140/2019_receitas.csv',
#  'raw/42_420140/2019_despesas.csv',
#  'raw/29_293030/2019_receitas.csv',
#  'raw/29_293030/2019_despesas.csv',
#  'raw/41_411500/2019_receitas.csv',
#  'raw/41_411500/2019_despesas.csv',
#  'raw/27_270290/2019_receitas.csv',
#  'raw/27_270290/2019_despesas.csv',
#  'raw/29_292530/2019_receitas.csv',
#  'raw/29_292530/2020_despesas.csv',
# ...
