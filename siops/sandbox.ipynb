# %%
from scrapy import Request

url = 'http://siops.datasus.gov.br/rel_LRF.php'

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:79.0) Gecko/20100101 Firefox/79.0",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Content-Type": "application/x-www-form-urlencoded",
    "Origin": "http://siops.datasus.gov.br",
    "Connection": "keep-alive",
    "Referer": "http://siops.datasus.gov.br/consleirespfiscal.php?S=1&UF=35;&Municipio=354340;&Ano=2019&Periodo=1",
    "Upgrade-Insecure-Requests": "1"
}

cookies = {
    "PHPSESSID": "9g9ilpn6jrmc9m5rt4dete0in5"
}

body = 'cmbAno=2019&cmbUF=35&cmbPeriodo=1&cmbMunicipio%5B%5D=354340&BtConsultar=Consultar'

request = Request(
    url=url,
    method='POST',
    dont_filter=True,
    cookies=cookies,
    headers=headers,
    body=body,
)

#fetch(request)

# %%
request.

# %%
import pandas as pd

# %%
df = pd.read_csv('ibge.csv')

# %%
df.columns
# Out:
# Index(['Cod Municipio', 'REGIAO', 'COD UF', 'UF', 'NOME MUNIC'], dtype='object')

# %%
[f'{row._1}-{row._3}' for row in df.itertuples()]
# Out:
# ['1100015-11',
#  '1100023-11',
#  '1100031-11',
#  '1100049-11',
#  '1100056-11',
#  '1100064-11',
#  '1100072-11',
#  '1100080-11',
#  '1100098-11',
#  '1100106-11',
#  '1100114-11',
#  '1100122-11',
#  '1100130-11',
#  '1100148-11',
#  '1100155-11',
#  '1100189-11',
#  '1100205-11',
#  '1100254-11',
#  '1100262-11',
#  '1100288-11',
#  '1100296-11',
#  '1100304-11',
#  '1100320-11',
#  '1100338-11',
#  '1100346-11',
#  '1100379-11',
#  '1100403-11',
#  '1100452-11',
#  '1100502-11',
#  '1100601-11',
#  '1100700-11',
#  '1100809-11',
#  '1100908-11',
#  '1100924-11',
#  '1100940-11',
#  '1101005-11',
#  '1101104-11',
#  '1101203-11',
#  '1101302-11',
#  '1101401-11',
#  '1101435-11',
#  '1101450-11',
#  '1101468-11',
#  '1101476-11',
#  '1101484-11',
#  '1101492-11',
#  '1101500-11',
#  '1101559-11',
#  '1101609-11',
#  '1101708-11',
#  '1101757-11',
#  '1101807-11',
#  '1200013-12',
#  '1200054-12',
#  '1200104-12',
#  '1200138-12',
#  '1200179-12',
#  '1200203-12',
# ...

# %%
body.find('&cmbMunicipio%5B%5D=')
# Out:
# 33

# %%
body[body.find('&cmbMunicipio%5B%5D=')+len('&cmbMunicipio%5B%5D='):body.find('&BtConsultar=')]
# Out:
# '354340'

# %%
len('&cmbMunicipio%5B%5D=')
# Out:
# 20

# %%
s1 = 'as'

# %%
s==s1
# Out:
# True

# %%
body.find('&cmbMunicipio%5B%5D=')+len('&cmbMunicipio%5B%5D=')
# Out:
# 53

# %%
file = open('teste.csv', 'w')

# %%
file._checkWritable()
# Out:
# True

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
f'''cmbAno=2019&cmbUF={
                3
            }&cmbPeriodo=1&cmbMunicipio%5B%5D={
                4534
            }&BtConsultar=Consultar'''
# Out:
# 'cmbAno=2019&cmbUF=3&cmbPeriodo=1&cmbMunicipio%5B%5D=4534&BtConsultar=Consultar'

# %%
import  scrapy

# %%
df = pd.read_csv('ibge.csv')

# %%
df.iloc[0:10][['Cod Municipio','COD UF']].values
# Out:
# array([[1100015,      11],
#        [1100023,      11],
#        [1100031,      11],
#        [1100049,      11],
#        [1100056,      11],
#        [1100064,      11],
#        [1100072,      11],
#        [1100080,      11],
#        [1100098,      11],
#        [1100106,      11]])

# %%
url = 'http://siops.datasus.gov.br/rel_LRF.php'

cookies = {
    "PHPSESSID": "9g9ilpn6jrmc9m5rt4dete0in5"
}

r_list = []
for row in [[1100015,      11],
       [1100023,      11],
       [1100031,      11],
       [1100049,      11],
       [1100056,      11],
       [1100064,      11],
       [1100072,      11],
       [1100080,      11],
       [1100098,      11],
       [1100106,      11]]:

    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:79.0) Gecko/20100101 Firefox/79.0",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Accept-Language": "en-US,en;q=0.5",
        "Content-Type": "application/x-www-form-urlencoded",
        "Origin": "http://siops.datasus.gov.br",
        "Connection": "keep-alive",
        "Referer": f"""http://siops.datasus.gov.br/consleirespfiscal.php?S=1&UF={
            row[1]
            };&Municipio={
            row[0]
            };&Ano=2019&Periodo=1""",
        "Upgrade-Insecure-Requests": "1"
    }

    body = f'''cmbAno=2019&cmbUF={
        row[1]
    }&cmbPeriodo=1&cmbMunicipio%5B%5D={
        row[0]
    }&BtConsultar=Consultar'''

    r_list.append( scrapy.Request(
        url=url,
        method='POST',
        dont_filter=True,
        cookies=cookies,
        headers=headers,
        body=body
    ))

# %%
df[df['NOME MUNIC']=='Anadia']
# Out:
#       Cod Municipio        REGIAO  COD UF       UF NOME MUNIC
# 1651        2700201  2 - Nordeste      27  Alagoas     Anadia

# %%
df
# Out:
#       Cod Municipio            REGIAO  COD UF                UF  \
# 0           1100015         1 - Norte      11          Rondônia
# 1           1100023         1 - Norte      11          Rondônia
# 2           1100031         1 - Norte      11          Rondônia
# 3           1100049         1 - Norte      11          Rondônia
# 4           1100056         1 - Norte      11          Rondônia
# ...             ...               ...     ...               ...
# 5565        5222005  5 - Centro-Oeste      52             Goiás
# 5566        5222054  5 - Centro-Oeste      52             Goiás
# 5567        5222203  5 - Centro-Oeste      52             Goiás
# 5568        5222302  5 - Centro-Oeste      52             Goiás
# 5569        5300108  5 - Centro-Oeste      53  Distrito Federal
#
#                  NOME MUNIC
# 0     Alta Floresta D'Oeste
# 1                 Ariquemes
# 2                    Cabixi
# 3                    Cacoal
# 4                Cerejeiras
# ...
